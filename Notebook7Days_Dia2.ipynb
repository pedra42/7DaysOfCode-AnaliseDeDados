# %%
import pandas as pd

df = pd.read_csv("C:/Users/barro/Downloads/RegistrosMesclados.csv")

df["matricula_ou_siape"] = df["matricula_ou_siape"].astype(str)

print(df.info())
print(df.columns)
print(df.dtypes)
print(df.loc[df["matricula_ou_siape"] == "20200045888.0"])
print("gO")
df.to_csv("DataFrameDesafio_2.csv", index=None)


#esta parte do código apenas muda o tipo de dado das matrículas.

# %%
print(df.info())
print(df[df['id_emprestimo'].duplicated() == True].sort_values(by='id_emprestimo'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235180 entries, 0 to 2235179
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           float64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           float64
#  12  registro_sistema      float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 221.7+ MB
# None
#          id_emprestimo codigo_barras                 data_renovacao  \
# 4               709684       L095049                            NaN
# 5               709685       L167050                            NaN
# ...

# %%
print(df.duplicated(['id_emprestimo'], keep=False))
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 2235175    False
# 2235176    False
# 2235177    False
# 2235178    False
# 2235179    False
# Length: 2235180, dtype: bool

# %%
df[df.duplicated(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
       'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
       'id_exemplar', 'colecao', 'biblioteca', 'status_material',
       'localizacao', 'registro_sistema'], keep=False)].sort_values(by='id_emprestimo')
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 4               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 5               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# ...                ...           ...                            ...
# 1506524        2461097    2014083427                            NaN
# 1506517        2461098    2014049460                            NaN
# 1506525        2461098    2014049460                            NaN
# 1506518        2461099    2012008348  2016/06/27 20:35:46.855000000
# 1506526        2461099    2012008348  2016/06/27 20:35:46.855000000
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
df[df.duplicated(df.columns, keep=False)].sort_values(by='id_emprestimo')
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 4               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 5               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# ...                ...           ...                            ...
# 1506524        2461097    2014083427                            NaN
# 1506517        2461098    2014049460                            NaN
# 1506525        2461098    2014049460                            NaN
# 1506518        2461099    2012008348  2016/06/27 20:35:46.855000000
# 1506526        2461099    2012008348  2016/06/27 20:35:46.855000000
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
df_sem_duplicata = df.drop_duplicates(keep=False)
df_sem_duplicata = df_sem_duplicata.reset_index(drop = True)
print(df_sem_duplicata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235117 entries, 0 to 2235116
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           float64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           float64
#  12  registro_sistema      float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 221.7+ MB
# None

# %%
df_sem_duplicata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235117 entries, 0 to 2235116
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           float64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           float64
#  12  registro_sistema      float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 221.7+ MB

# %%
df_sem_duplicata.to_csv("DataFrameDesafio_3.csv", index=None)
